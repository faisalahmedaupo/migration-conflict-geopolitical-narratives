# %% [markdown]
# # Data validation and narrative baseline
# This notebook is designed for the v2.0 pipeline. Demo outputs are illustrative only.

# %%
import pandas as pd
df = pd.read_csv('../data/raw/gdelt_articles.csv')
df.head()

# %%
df.info()
df.isna().sum()
